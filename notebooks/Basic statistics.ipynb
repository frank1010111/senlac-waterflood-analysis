# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import seaborn as sns
import os, sys

sys.path.append(os.path.expanduser('~/Dropbox/ROZ/code/pyCRM'))
from pyCRM import CRM
sns.set()
RESULTS_DIR = 'results_Jerry/'

# %%
gains = pd.read_csv(RESULTS_DIR + 'Senlac_gains.csv', index_col=0).rename_axis(index='producer', columns='injector')
gains_producer = pd.read_csv(RESULTS_DIR + 'Senlac_gains_producer.csv', index_col=0).rename_axis(index='producer')

# %%
gains.stack().head()
# Out:
# producer  injector
# 0         0           1.417613e-01
#           1           1.000000e+00
#           2           3.440596e-33
#           3           1.490691e-33
#           4           6.087331e-40
# dtype: float64

# %%
gains_producer
# Out:
#                      0
# producer
# 0         1.000000e+00
# 1         9.577739e-01
# 2         3.152253e-01
# 3         1.000000e+00
# 4         6.290795e-01
# 5         3.688432e-01
# 6         5.979357e-01
# 7         6.271664e-01
# 8         6.152921e-24
# 9         5.313861e-01
# 10        1.000000e+00
# 11        7.555909e-01
# 12        1.606493e-01
# 13        5.903123e-29
# 14        5.021586e-01
# 15        6.546432e-01
# 16        1.000000e+00
# 17        5.905877e-01
# 18        1.000000e+00
# 19        8.273515e-01
# 20        1.000000e+00
# 21        3.124420e-22
# 22        1.853648e-01
